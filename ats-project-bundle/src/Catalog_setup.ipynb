# %%
# %sql
CREATE CATALOG IF NOT EXISTS ats_dev
COMMENT 'Catalog for dev environment ats';

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS ats_dev.ats_db
COMMENT 'Schema for dev environment ats';

# %%
# %sql
CREATE VOLUME IF NOT EXISTS ats_dev.ats_db.data_ingestion
COMMENT 'volume for data ingestion dev';

# %%
# %sql
CREATE CATALOG IF NOT EXISTS ats_uat
COMMENT 'Catalog for uat/QA environment ats';

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS ats_uat.ats_db
COMMENT 'Schema for uat/QA environment ats';

# %%
# %sql
CREATE VOLUME IF NOT EXISTS ats_uat.ats_db.data_ingestion
COMMENT 'volume for data ingestion uat';
