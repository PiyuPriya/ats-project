# %%
# %run ./01-ATSConfigs

# %%
# %run ./03-Endpoints

# %%
# %run ./04-VectorSearch

# %%
# %run ./05-ProfileIngestion

# %%
# %run ./08-BronzeProfile

# %%
# %run ./09-SilverProfile

# %%
# %run ./11-ProfileIndex

# %%
# %run ./06-JDIngestion

# %%
# %run ./07-BronzeJD

# %%
# %run ./10-SilverJD

# %%
# %run ./12-ProfileSearch
